# %% [markdown]
# <img src="https://cdn.siberian.dev/siberian.png" alt="Siberian Logo">

# %% [markdown]
# # Text Generation using GPT Neo 125M

# %% [markdown]
# This Code Template is for the Text Generation task, which is a problem associated with NLG(Natural Language Generation). In this Project, GPT Neo 125M is utilized for Text Generation. GPT-Neo 125M is a transformer model designed using EleutherAI's replication of the GPT-3 architecture.

# %% [markdown]
# ### Required Packages

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %% [markdown]
# ### GPT-Neo 125M
#
# GPT-Neo 125M is a transformer model designed using EleutherAI's replication of the GPT-3 architecture. GPT-Neo refers to the class of models, while 125M represents the number of parameters of this particular pre-trained model.
#
# You can use this model directly with a pipeline for text generation. This example generates a different sequence each time it's run:

# %%
generator = pipeline('text-generation', model='EleutherAI/gpt-neo-125M')

# %% [markdown]
# ### Text Generation

# %%
generator("Nice to", max_length=60, num_return_sequences=1,do_sample=True,)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Nice to hear from the one and only Paulista. The reason that we are more loyal to the Pope is because all the other Catholic bishops have gotten one. And even the Pope has turned to his own family for help too. It's an unfortunate but important truth - this is not about us."}]
