# %% [markdown]
# <img src="https://cdn.siberian.dev/siberian.png" alt="Siberian Logo">

# %% [markdown]
# ### Deep One-Class Classification With MaxAbsScaler

# %% [markdown]
# This code template illustrates Anomaly detection using the DeepSVDD Algorithm implementation of the PyOd library. DeepSVDD trains a neural network while minimizing the volume of a hypersphere that encloses the network representations of the data, forcing the network to extract the common factors of variation. Along with the Data rescaling technique, MaxAbsScaler from sci-kit learn.

# %% [markdown]
# ### Required Packages

# %%
# !pip install plotly
# !pip install pyod
# !pip install tensorflow #For DeepSVDD

# %%
import time
import warnings
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import Isomap
from pyod.models.deep_svdd import DeepSVDD
from sklearn.preprocessing import LabelEncoder, MaxAbsScaler
from sklearn.model_selection import train_test_split
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Initialization
#
# Filepath of CSV file

# %%
file_path= ''

# %% [markdown]
# List of features which are  required for model training

# %%
features=[]

# %% [markdown]
# ### Data Fetching
#
# Pandas is an open-source, BSD-licensed library providing high-performance, easy-to-use data manipulation and data analysis tools.
#
# We will use panda's library to read the CSV file using its storage path.And we use the head function to display the initial row or entry.

# %%
df=pd.read_csv(file_path)
df.head()
# Out:
#    duration protocoltype   service  ... dsthostsrvrerrorrate  lastflag   attack
# 0         0          tcp  ftp_data  ...                 0.00        20   normal
# 1         0          udp     other  ...                 0.00        15   normal
# 2         0          tcp   private  ...                 0.00        19  neptune
# 3         0          tcp      http  ...                 0.01        21   normal
# 4         0          tcp      http  ...                 0.00        21   normal
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Feature Selections
#
# It is the process of reducing the number of input variables when developing a predictive model. Used to reduce the number of input variables to both reduce the computational cost of modelling and, in some cases, to improve the performance of the model.
#
# We will assign all the required input features to X.

# %%
X=[features]

# %% [markdown]
# ### Data Preprocessing
#
# Since the majority of the machine learning models in the Sklearn library doesn't handle string category data and Null value, we have to explicitly remove or replace null values. The below snippet have functions, which removes the null value if any exists. And convert the string classes data in the datasets by encoding them to integer classes.

# %%
def NullClearner(df):
    if(isinstance(df, pd.Series) and (df.dtype in ["float64","int64"])):
        df.fillna(df.mean(),inplace=True)
        return df
    elif(isinstance(df, pd.Series)):
        df.fillna(df.mode()[0],inplace=True)
        return df
    else:return df
def EncodeX(df):
    return pd.get_dummies(df)

# %% [markdown]
# Calling preprocessing functions on the feature set.

# %%
x=X.columns.to_list()
for i in x:
    X[i]=NullClearner(X[i])  
X=EncodeX(X)
X.head()
# Out:
#    duration  srcbytes  dstbytes  ...  flag_S1  flag_SF  flag_SH
# 0         0       491         0  ...        0        1        0
# 1         0       146         0  ...        0        1        0
# 2         0         0         0  ...        0        0        0
# 3         0       232      8153  ...        0        1        0
# 4         0       199       420  ...        0        1        0
#
# [5 rows x 103 columns]

# %% [markdown]
# ### Data Rescaling
#
# **MaxAbsScaler**
# Scale each feature by its maximum absolute value.
#
# This estimator scales and translates each feature individually such that the maximal absolute value of each feature in the training set will be 1.0. It does not shift/center the data, and thus does not destroy any sparsity.
#
# This scaler can also be applied to sparse CSR or CSC matrices.
#
# Refer [API](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MaxAbsScaler.html) for the parameters

# %%
X_Scaled=MaxAbsScaler().fit_transform(X)
X_Scaled=pd.DataFrame(data = X_Scaled,columns = X.columns)
X_Scaled.head()
# Out:
#    duration  srcbytes  dstbytes  ...  flag_S1  flag_SF  flag_SH
# 0       0.0  0.000096  0.000000  ...      0.0      1.0      0.0
# 1       0.0  0.000028  0.000000  ...      0.0      1.0      0.0
# 2       0.0  0.000000  0.000000  ...      0.0      0.0      0.0
# 3       0.0  0.000045  0.054820  ...      0.0      1.0      0.0
# 4       0.0  0.000039  0.002824  ...      0.0      1.0      0.0
#
# [5 rows x 103 columns]

# %% [markdown]
# ### Data Splitting
#
# The train-test split is a procedure for evaluating the performance of an algorithm. The procedure involves taking a dataset and dividing it into two subsets. The first subset is utilized to fit/train the model. The second subset is used for prediction. The main motive is to estimate the performance of the model on new data.

# %%
x_train,x_test=train_test_split(X_Scaled,test_size=0.2,random_state=123)

# %% [markdown]
# ### Model
#
# Deep One-Class Classifier with AutoEncoder (AE) is a type of neural networks for learning useful data representations in an unsupervised way. DeepSVDD trains a neural network while minimizing the volume of a hypersphere that encloses the network representations of the data, forcing the network to extract the common factors of variation
#
# #### Tuning parameters
#
# 1. c (float, optional (default='forwad_nn_pass'))
# >Deep SVDD center, the default will be calculated based on network initialization first forward pass. To get repeated results set random_state if c is set to None.
#
# 2. use_ae (bool, optional (default=False)
# >The AutoEncoder type of DeepSVDD it reverse neurons from hidden_neurons if set to True.
#
# 3. hidden_neurons (list, optional (default=[64, 32]))
# >The number of neurons per hidden layers. if use_ae is True, neurons will be reversed eg. [64, 32] -> [64, 32, 32, 64, n_features]
#
# 4. hidden_activation (str, optional (default='relu'))
# >Activation function to use for hidden layers. All hidden layers are forced to use the same type of activation. See https://keras.io/activations/
#
# 5. output_activation (str, optional (default='sigmoid'))
# >Activation function to use for output layer. See https://keras.io/activations/
#
# 6. optimizer (str, optional (default='adam'))
# >String (name of optimizer) or optimizer instance. See https://keras.io/optimizers/
#
# 7. epochs (int, optional (default=100))
# >Number of epochs to train the model.
#
# 8. batch_size (int, optional (default=32))
# >Number of samples per gradient update.
#
# 9. contamination (float in (0., 0.5), optional (default=0.1))
# >The amount of contamination of the data set, i.e. the proportion of outliers in the data set. When fitting this is used to define the threshold on the decision function.
#
# [For more information](https://pyod.readthedocs.io/en/latest/pyod.models.html#pyod.models.deep_svdd.DeepSVDD)

# %%
model = DeepSVDD(contamination=0.3, epochs=100, batch_size=16)
model.fit(x_train)
# Out:
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 103)]             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                6656
# _________________________________________________________________
# net_output (Dense)           (None, 32)                2080
# _________________________________________________________________
# tf.math.subtract_7 (TFOpLamb (None, 32)                0
# _________________________________________________________________
# tf.math.pow_7 (TFOpLambda)   (None, 32)                0
# _________________________________________________________________
# tf.math.reduce_sum_7 (TFOpLa (None,)                   0
# _________________________________________________________________
# tf.math.reduce_mean_7 (TFOpL ()                        0
# _________________________________________________________________
# tf.__operators__.add_7 (TFOp ()                        0
# _________________________________________________________________
# add_loss_7 (AddLoss)         ()                        0
# =================================================================
# Total params: 8,736
# Trainable params: 8,736
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 45/45 [==============================] - 1s 4ms/step - loss: 10.3425 - val_loss: 7.2589
# Epoch 2/100
# 45/45 [==============================] - 0s 2ms/step - loss: 6.0793 - val_loss: 5.7336
# Epoch 3/100
# 45/45 [==============================] - 0s 2ms/step - loss: 4.9099 - val_loss: 4.7545
# Epoch 4/100
# 45/45 [==============================] - 0s 2ms/step - loss: 4.0549 - val_loss: 4.0015
# Epoch 5/100
# 45/45 [==============================] - 0s 2ms/step - loss: 3.4268 - val_loss: 3.4185
# Epoch 6/100
# 45/45 [==============================] - 0s 2ms/step - loss: 2.8702 - val_loss: 2.9358
# Epoch 7/100
# 45/45 [==============================] - 0s 2ms/step - loss: 2.4646 - val_loss: 2.5609
# Epoch 8/100
# 45/45 [==============================] - 0s 2ms/step - loss: 2.1556 - val_loss: 2.2799
# Epoch 9/100
# 45/45 [==============================] - 0s 3ms/step - loss: 1.8844 - val_loss: 2.0417
# Epoch 10/100
# 45/45 [==============================] - 0s 2ms/step - loss: 1.6730 - val_loss: 1.8537
# Epoch 11/100
# 45/45 [==============================] - 0s 2ms/step - loss: 1.4926 - val_loss: 1.7105
# Epoch 12/100
# 45/45 [==============================] - 0s 2ms/step - loss: 1.3337 - val_loss: 1.5410
# Epoch 13/100
# 45/45 [==============================] - 0s 2ms/step - loss: 1.2075 - val_loss: 1.4369
# Epoch 14/100
# 45/45 [==============================] - 0s 2ms/step - loss: 1.1031 - val_loss: 1.3592
# Epoch 15/100
# 45/45 [==============================] - 0s 2ms/step - loss: 1.0222 - val_loss: 1.2777
# Epoch 16/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.9454 - val_loss: 1.2272
# Epoch 17/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.8818 - val_loss: 1.1922
# Epoch 18/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.8315 - val_loss: 1.1150
# Epoch 19/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.7824 - val_loss: 1.0641
# Epoch 20/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.7442 - val_loss: 1.0157
# Epoch 21/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.7109 - val_loss: 0.9871
# Epoch 22/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.6784 - val_loss: 0.9723
# Epoch 23/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.6518 - val_loss: 0.9531
# Epoch 24/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.6268 - val_loss: 0.9530
# Epoch 25/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.6080 - val_loss: 0.9166
# Epoch 26/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5905 - val_loss: 0.9094
# Epoch 27/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5779 - val_loss: 0.8759
# Epoch 28/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5654 - val_loss: 0.8853
# Epoch 29/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5513 - val_loss: 0.8313
# Epoch 30/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.5329 - val_loss: 0.8435
# Epoch 31/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5237 - val_loss: 0.8321
# Epoch 32/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5161 - val_loss: 0.8351
# Epoch 33/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5092 - val_loss: 0.8132
# Epoch 34/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5029 - val_loss: 0.8157
# Epoch 35/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.5012 - val_loss: 0.8090
# Epoch 36/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4964 - val_loss: 0.7903
# Epoch 37/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4863 - val_loss: 0.7871
# Epoch 38/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4804 - val_loss: 0.7777
# Epoch 39/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4711 - val_loss: 0.7654
# Epoch 40/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4708 - val_loss: 0.7603
# Epoch 41/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4642 - val_loss: 0.7472
# Epoch 42/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4633 - val_loss: 0.7564
# Epoch 43/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4597 - val_loss: 0.7393
# Epoch 44/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4581 - val_loss: 0.7540
# Epoch 45/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4571 - val_loss: 0.7337
# Epoch 46/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4559 - val_loss: 0.7399
# Epoch 47/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4546 - val_loss: 0.7385
# Epoch 48/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4551 - val_loss: 0.7375
# Epoch 49/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4547 - val_loss: 0.7309
# Epoch 50/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.4529 - val_loss: 0.7313
# Epoch 51/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4524 - val_loss: 0.7282
# Epoch 52/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4520 - val_loss: 0.7315
# Epoch 53/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4516 - val_loss: 0.7268
# Epoch 54/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4512 - val_loss: 0.7296
# Epoch 55/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4508 - val_loss: 0.7281
# Epoch 56/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4506 - val_loss: 0.7401
# Epoch 57/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4505 - val_loss: 0.7217
# Epoch 58/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4504 - val_loss: 0.7241
# Epoch 59/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4503 - val_loss: 0.7234
# Epoch 60/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.4502 - val_loss: 0.7234
# Epoch 61/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4502 - val_loss: 0.7231
# Epoch 62/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4501 - val_loss: 0.7229
# Epoch 63/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4501 - val_loss: 0.7227
# Epoch 64/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4501 - val_loss: 0.7232
# Epoch 65/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4500 - val_loss: 0.7224
# Epoch 66/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4500 - val_loss: 0.7223
# Epoch 67/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4500 - val_loss: 0.7222
# Epoch 68/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4500 - val_loss: 0.7219
# Epoch 69/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4500 - val_loss: 0.7218
# Epoch 70/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7219
# Epoch 71/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7219
# Epoch 72/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7218
# Epoch 73/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7212
# Epoch 74/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7209
# Epoch 75/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7209
# Epoch 76/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7209
# Epoch 77/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7207
# Epoch 78/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7207
# Epoch 79/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7206
# Epoch 80/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7206
# Epoch 81/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7206
# Epoch 82/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7206
# Epoch 83/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7206
# Epoch 84/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7205
# Epoch 85/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7206
# Epoch 86/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7205
# Epoch 87/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7205
# Epoch 88/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7203
# Epoch 89/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7203
# Epoch 90/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7205
# Epoch 91/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7204
# Epoch 92/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7204
# Epoch 93/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7205
# Epoch 94/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7205
# Epoch 95/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7205
# Epoch 96/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7203
# Epoch 97/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7202
# Epoch 98/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7203
# Epoch 99/100
# 45/45 [==============================] - 0s 3ms/step - loss: 0.4499 - val_loss: 0.7203
# Epoch 100/100
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4499 - val_loss: 0.7203
# DeepSVDD(batch_size=16,
#      c=array([0.1    , 0.1    , 0.9271 , 0.21007, 0.6336 , 0.65325, 0.13697,
#        0.27211, 0.18292, 0.67595, 0.1    , 0.26903, 0.15144, 0.50773,
#        0.13322, 0.20535, 0.31704, 0.52829, 0.45639, 0.79105, 0.44825,
#        0.23239, 0.1    , 0.1    , 0.1    , 0.60763, 0.29255, 0.20088,
#        0.21636, 0.11658, 0.14855, 0.33774], dtype=float32),
#      contamination=0.3, dropout_rate=0.2, epochs=100,
#      hidden_activation='relu', hidden_neurons=[64, 32], l2_regularizer=0.1,
#      optimizer='adam', output_activation='sigmoid', preprocessing=True,
#      random_state=None, use_ae=False, validation_size=0.1, verbose=1)

# %% [markdown]
# ### Anomaly Prediction

# %%
result=x_test.copy(deep=True)
result['Anomaly']=model.predict(x_test)
result.head()
# Out:
#      duration  srcbytes  dstbytes  ...  flag_SF  flag_SH  Anomaly
# 131       0.0  0.000000  0.000000  ...      0.0      0.0        1
# 203       0.0  0.000167  0.003866  ...      1.0      0.0        0
# 50        0.0  0.000059  0.003349  ...      1.0      0.0        0
# 585       0.0  0.001148  0.000000  ...      1.0      0.0        0
# 138       0.0  0.000201  0.000000  ...      1.0      0.0        1
#
# [5 rows x 104 columns]

# %% [markdown]
# ### Anomaly Visualization

# %% [markdown]
# #### Bar Plot

# %%
result['Anomaly'].value_counts().plot(kind='bar',color=['green','red'])

# %% [markdown]
# **creator: Virat Chowdary, GitHub: [profile](https://github.com/viratchowdary21)**
